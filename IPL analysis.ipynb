# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl =pd.read_csv(r"C:\Users\Administrator\Documents\deliveries.csv")
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# oveview of this data
ipl.info
# Out:
# <bound method DataFrame.info of         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# ...

# %%
# basic statistics
ipl.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#check for missing values 
ipl.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
# columns names 
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# to data clean data 
ipl.drop_duplicates(inplace=True)

# %%
# to fill and drop the null values
ipl.dropna()
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 199            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150402       636       2  Royal Challengers Bangalore
# 150422       636       2  Royal Challengers Bangalore
# 150438       636       2  Royal Challengers Bangalore
# 150448       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball         batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5       DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3        S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2    MC Henriques  Yuvraj Singh
# ...

# %%
ipl['batsman'].value_counts().head(30)
# Out:
# batsman
# V Kohli           3494
# G Gambhir         3433
# SK Raina          3369
# RG Sharma         3274
# S Dhawan          3005
# RV Uthappa        2960
# DA Warner         2902
# MS Dhoni          2680
# AM Rahane         2602
# CH Gayle          2532
# AB de Villiers    2402
# KD Karthik        2360
# JH Kallis         2291
# BB McCullum       2181
# M Vijay           2092
# YK Pathan         2076
# PA Patel          2060
# Yuvraj Singh      2050
# SR Tendulkar      2043
# AT Rayudu         1964
# SR Watson         1949
# R Dravid          1918
# SE Marsh          1913
# MK Pandey         1901
# V Sehwag          1833
# DR Smith          1803
# KA Pollard        1674
# MEK Hussey        1648
# JP Duminy         1634
# AC Gilchrist      1555
# Name: count, dtype: int64

# %%
ipl['bowler'].value_counts().head(30)
# Out:
# bowler
# Harbhajan Singh    2989
# A Mishra           2703
# SL Malinga         2694
# P Kumar            2637
# PP Chawla          2594
# R Ashwin           2359
# Z Khan             2276
# R Vinay Kumar      2161
# DW Steyn           2159
# IK Pathan          2113
# DJ Bravo           2110
# B Kumar            2054
# UT Yadav           2033
# A Nehra            1974
# RA Jadeja          1962
# SR Watson          1961
# SP Narine          1956
# PP Ojha            1945
# RP Singh           1874
# JA Morkel          1807
# JH Kallis          1799
# I Sharma           1713
# M Morkel           1699
# R Bhatia           1661
# AB Dinda           1589
# M Muralitharan     1581
# L Balaji           1574
# MM Sharma          1566
# SK Trivedi         1557
# DS Kulkarni        1485
# Name: count, dtype: int64

# %%
data = ipl.to_numpy()

# %%
# print shape of data
print ("shape:",data.shape)
# Out:
# shape: (150459, 21)

# %%
print("first 5 rows:\n",data[:10])
# Out:
# first 5 rows:
#  [[1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 1 'DA Warner'
#   'S Dhawan' 'TS Mills' 0 0 0 0 0 0 0 0 0 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 2 'DA Warner'
#   'S Dhawan' 'TS Mills' 0 0 0 0 0 0 0 0 0 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 3 'DA Warner'
#   'S Dhawan' 'TS Mills' 0 0 0 0 0 0 4 0 4 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 4 'DA Warner'
#   'S Dhawan' 'TS Mills' 0 0 0 0 0 0 0 0 0 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 5 'DA Warner'
#   'S Dhawan' 'TS Mills' 0 2 0 0 0 0 0 2 2 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 6 'S Dhawan'
#   'DA Warner' 'TS Mills' 0 0 0 0 0 0 0 0 0 nan nan nan]
#  [1 1 'Sunrisers Hyderabad' 'Royal Challengers Bangalore' 1 7 'S Dhawan'
#   'DA Warner' 'TS Mills' 0 0 0 1 0 0 0 1 1 nan nan nan]
# ...

# %%
# Find number of unique batsmen

unique_batsmen = ipl['batsman'].nunique()

print("Number of unique batsmen:", unique_batsmen)
# Out:
# Number of unique batsmen: 461

# %%
# Calculate total runs
total_runs = ipl['total_runs'].sum()

print("Total runs scored in the entire dataset:", total_runs)
# Out:
# Total runs scored in the entire dataset: 194313

# %%
# Find the batsman with the highest runs

batsman_runs = ipl.groupby('batsman')['batsman_runs'].sum()
top_batsman = batsman_runs.sort_values(ascending=False).head(1)

print("Batsman with the most total runs:")
print(top_batsman)
# Out:
# Batsman with the most total runs:
# batsman
# SK Raina    4548
# Name: batsman_runs, dtype: int64

# %%
# Find the bowler who gave the most runs

bowler_runs = ipl.groupby('bowler')['total_runs'].sum()


most_expensive_bowler = bowler_runs.sort_values(ascending=False).head(1)

print("Bowler who gave the most runs:")
print(most_expensive_bowler)
# Out:
# Bowler who gave the most runs:
# bowler
# Harbhajan Singh    3453
# Name: total_runs, dtype: int64

# %%
# Get the bowler with the most deliveries

balls_bowled = ipl['bowler'].value_counts()


top_bowler = balls_bowled.head(1)

print("Bowler who bowled the most deliveries (balls):")
print(top_bowler)
# Out:
# Bowler who bowled the most deliveries (balls):
# bowler
# Harbhajan Singh    2989
# Name: count, dtype: int64

# %%
# How many sixes were hit in total


total_sixes = ipl[ipl['batsman_runs'] == 6].shape[0]

print("Total number of sixes hit:", total_sixes)
# Out:
# Total number of sixes hit: 6523

# %%
# how many fours were hit in total

total_fours = ipl[ipl['batsman_runs'] == 4].shape[0]

print("Total number of fours hit:", total_fours)
# Out:
# Total number of fours hit: 17033

# %%
# Which batsman hit the most sixes

sixes = ipl[ipl['batsman_runs'] == 6]


sixes_by_batsman = sixes['batsman'].value_counts()


top_sixer = sixes_by_batsman.head(1)

print("Batsman who hit the most sixes:")
print(top_sixer)
# Out:
# Batsman who hit the most sixes:
# batsman
# CH Gayle    266
# Name: count, dtype: int64

# %%
#Which batsman hit the most fours

fours = ipl[ipl['batsman_runs'] == 4]

fours_by_batsman = fours['batsman'].value_counts()

top_fours_batsman = fours_by_batsman.head(1)

print("Batsman who hit the most fours:")
print(top_fours_batsman)
# Out:
# Batsman who hit the most fours:
# batsman
# G Gambhir    484
# Name: count, dtype: int64

# %%
#How many players were dismissed (got out) in total?
total_dismissals = ipl['player_dismissed'].notnull().sum()

print("Total number of players dismissed:", total_dismissals)
# Out:
# Total number of players dismissed: 7438

# %%
# What is the most common way a player gets out (dismissal type)

dismissal_counts = ipl['dismissal_kind'].value_counts()


most_common_dismissal = dismissal_counts.head(1)

print("Most common dismissal type:")
print(most_common_dismissal)
# Out:
# Most common dismissal type:
# dismissal_kind
# caught    4373
# Name: count, dtype: int64

# %%
# How many dot balls were bowled in total

dot_balls = ipl[ipl['total_runs'] == 0]

# Count the number of such deliveries
total_dot_balls = dot_balls.shape[0]

print("Total number of dot balls bowled:", total_dot_balls)
# Out:
# Total number of dot balls bowled: 53305

# %%
# Which over has the highest number of runs scored on average 

average_runs_per_over = ipl.groupby('over')['total_runs'].mean()


max_avg_over = average_runs_per_over.sort_values(ascending=False).head(1)

print("Over with the highest average runs scored:")
print(max_avg_over)
# Out:
# Over with the highest average runs scored:
# over
# 20    1.707736
# Name: total_runs, dtype: float64

# %%
# average runs scord per  over 

average_runs_per_over = ipl.groupby('over')['total_runs'].mean()


plt.figure(figsize=(10, 6))
average_runs_per_over.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Average Runs Scored Per Over (1 to 20)', fontsize=14)
plt.xlabel('Over Number', fontsize=12)
plt.ylabel('Average Runs', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# average runs scored per over(pie chart)

average_runs_per_over = ipl.groupby('over')['total_runs'].mean()

# pie chart
plt.figure(figsize=(8, 8))
plt.pie(average_runs_per_over, labels=average_runs_per_over.index,
        autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

plt.title('Average Runs Scored Per Over (Pie Chart)', fontsize=14)
plt.axis('equal')  
plt.show()

# %%
#Top 10 Batsmen by Total Runs (Bar Chart) 

top_batsmen = ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)

top_batsmen.plot(kind='bar', figsize=(10,6), color='green', edgecolor='black')
plt.title('Top 10 Batsmen by Total Runs')
plt.xlabel('Batsman')
plt.ylabel('Total Runs')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
 # Runs Per Over (Line Chart)

average_runs_per_over = ipl.groupby('over')['total_runs'].mean()

average_runs_per_over.plot(kind='line', marker='o', figsize=(10,5), color='purple')
plt.title('Average Runs per Over')
plt.xlabel('Over Number')
plt.ylabel('Average Runs')
plt.xticks(range(1, 21))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Top 10 Bowlers by Wickets (Bar Chart)

wickets = ipl[ipl['player_dismissed'].notnull()]
top_bowlers = wickets['bowler'].value_counts().head(10)

top_bowlers.plot(kind='bar', figsize=(10,6), color='red', edgecolor='black')
plt.title('Top 10 Bowlers by Wickets Taken')
plt.xlabel('Bowler')
plt.ylabel('Wickets')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
# top 10 batsmen bt balls faced 

balls_faced = ipl['batsman'].value_counts().head(10)

balls_faced.plot(kind='bar', figsize=(10,6), color='teal', edgecolor='black')
plt.title('Top 10 Batsmen by Balls Faced')
plt.xlabel('Batsman')
plt.ylabel('Balls Faced')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
#distrubution of extra runs

extras = ipl[['wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs']].sum()
extras = extras[extras > 0]

plt.figure(figsize=(7, 7))
plt.pie(extras, labels=extras.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Extra Runs', pad=30)
plt.axis('equal')
plt.show()

# %%
# types of runs scored by batsmens

run_types = ipl['batsman_runs'].value_counts().sort_index()

plt.figure(figsize=(7, 7))
plt.pie(run_types, labels=run_types.index, autopct='%1.1f%%', startangle=140)
plt.title('Types of Runs Scored by Batsmen')
plt.axis('equal')
plt.show()
